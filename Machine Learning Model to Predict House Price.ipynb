# %%
import pandas as pd

# %%
DF_train = pd.read_csv('/content/sample_data/california_housing_train.csv')

# %%
DF_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
DF_test = pd.read_csv('/content/sample_data/california_housing_test.csv')

# %%
DF_test
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
x_test = x_train = DF_test.iloc[:, 2:8]

# %%
y_test = DF_test.iloc[:, 8:9]

# %%
DF_train_final = DF_train.iloc[:, 0:]

# %%
DF_train_final
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
x_train = DF_train_final.iloc[:, 2:8]

# %%
x_train
# Out:
#        housing_median_age  total_rooms  total_bedrooms  population  \
# 0                    15.0       5612.0          1283.0      1015.0
# 1                    19.0       7650.0          1901.0      1129.0
# 2                    17.0        720.0           174.0       333.0
# 3                    14.0       1501.0           337.0       515.0
# 4                    20.0       1454.0           326.0       624.0
# ...                   ...          ...             ...         ...
# 16995                52.0       2217.0           394.0       907.0
# 16996                36.0       2349.0           528.0      1194.0
# 16997                17.0       2677.0           531.0      1244.0
# 16998                19.0       2672.0           552.0      1298.0
# 16999                52.0       1820.0           300.0       806.0
#
#        households  median_income
# 0           472.0         1.4936
# 1           463.0         1.8200
# 2           117.0         1.6509
# ...

# %%
y_train = DF_train_final.iloc[:, 8:9]

# %%
y_train
# Out:
#        median_house_value
# 0                 66900.0
# 1                 80100.0
# 2                 85700.0
# 3                 73400.0
# 4                 65500.0
# ...                   ...
# 16995            111400.0
# 16996             79000.0
# 16997            103600.0
# 16998             85800.0
# 16999             94600.0
#
# [17000 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
model_LR = LinearRegression()
model_LR.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_predict = model_LR.predict(x_test)

# %%
y_predict
# Out:
# array([[332098.0230497 ],
#        [213719.81431062],
#        [271260.04407687],
#        ...,
#        [ 85797.18665274],
#        [184332.1842798 ],
#        [440203.98512845]])

# %%
from sklearn import metrics
import numpy as np
print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_predict))
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_predict))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_predict)))
# Out:
# Mean Squared Error:  5808966246.7101965
# Mean Absolute Error:  55396.294616990475
# Root Mean Squared Error:  76216.57461937131

# %%
#Support Vector Regression

# %%
from sklearn.svm import SVR
model_SVR = SVR(kernel='linear')
model_SVR.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(kernel='linear')

# %%
y_predict2 = model_SVR.predict(x_test)

# %%
y_predict2
# Out:
# array([254082.90354013, 200441.03245663, 239169.11554716, ...,
#        128868.55187829, 183900.90403289, 275725.90487503])

# %%
print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_predict2))
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_predict2))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_predict2)))
# Out:
# Mean Squared Error:  8674170898.750322
# Mean Absolute Error:  69888.68160817654
# Root Mean Squared Error:  93135.2290959244

# %%
#RBF

# %%
from sklearn.svm import SVR
model_SVR_RBF = SVR(kernel = 'rbf')
model_SVR_RBF.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()

# %%
y_predict3 = model_SVR_RBF.predict(x_test)
y_predict3
# Out:
# array([180840.7816091 , 180009.30975318, 180749.23234753, ...,
#        179866.20634139, 179835.53926334, 180101.28368449])

# %%
print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_predict3))
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_predict3))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_predict3)))
# Out:
# Mean Squared Error:  13427202411.670599
# Mean Absolute Error:  86544.68824545684
# Root Mean Squared Error:  115875.80598067312

# %%
#Poly

# %%
from sklearn.svm import SVR
model_SVR_poly = SVR(kernel = 'poly')
model_SVR_poly.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR(kernel='poly')

# %%
y_predict4 = model_SVR_poly.predict(x_test)
y_predict4
# Out:
# array([180249.54122633, 179789.22172082, 180154.05936157, ...,
#        179773.13899496, 179772.48456016, 179816.13461057])

# %%
print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_predict4))
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_predict4))
print('Root Mean Squared Error: ', np.sqrt(metrics.mean_squared_error(y_test, y_predict4)))
# Out:
# Mean Squared Error:  13431609355.492432
# Mean Absolute Error:  86582.30293130188
# Root Mean Squared Error:  115894.82022718889

# %%
#Plot Graph of the Errors

# %%
modelLRerror=metrics.mean_squared_error(y_test, y_predict)
modelSVRerror=metrics.mean_squared_error(y_test, y_predict2)
modelSVRrbfError=metrics.mean_squared_error(y_test, y_predict3)
modelSVRpolyError=metrics.mean_squared_error(y_test, y_predict4)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
x_axis = ['model_LR', 'model_SVR','model_SVR_RBF', 'model_SVR_poly']
y_axis = [modelLRerror, modelSVRerror, modelSVRrbfError, modelSVRpolyError]
plt.xlabel('Type of model')
plt.ylabel('Values of error')
plt.title('Error comparison of models')
plt.bar(x_axis, y_axis)
plt.show()
